# %%
import pandas as pd
import numpy as np
import csv
import os
import stat
import os.path

# %%
pd.set_option('max_colwidth', 200)
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
df = pd.read_csv('Seattle_Trees.csv',encoding='utf-8-sig')

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13825 entries, 0 to 13999
# Data columns (total 14 columns):
# UNITID               13825 non-null object
# UNITDESC             13825 non-null object
# PRIMARYDISTRICTCD    13825 non-null object
# BOTANICAL_NAME       13825 non-null object
# SCIENTIFIC_NAME      13825 non-null object
# GROWSPACE            13825 non-null int64
# DIAM                 13825 non-null int64
# CONDITION_RATING     13825 non-null int64
# COMMON_NAME          13825 non-null object
# SHAPE_LAT            13825 non-null float64
# SHAPE_LNG            13825 non-null float64
# TOTAL_RANK           13825 non-null float64
# TOTAL_COUNT          13825 non-null float64
# GENUS                13825 non-null object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 1.6+ MB

# %%
df.head()
# Out:
#       UNITID                                                                                                                                                                                                 UNITDESC PRIMARYDISTRICTCD BOTANICAL_NAME              SCIENTIFIC_NAME  GROWSPACE  DIAM  CONDITION_RATING               COMMON_NAME  SHAPE_LAT   SHAPE_LNG  TOTAL_RANK  TOTAL_COUNT        GENUS
# 0  TRE-48779  1233 39TH AV E                                                                                                                                                                                      ...         DISTRICT3         HAWENG          Crataegus laevigata          8     7                 5  English Midland Hawthorn  47.630875 -122.282937         4.0       7206.0    Crataegus
# ...

# %%
df['PATH'] = df['UNITID']+'.jpg'

# %%
df['PATH'] = 'outdoor_trees/'+ df['PATH']

# %%
df['GENUS'].loc[df['GENUS'] == 'x'] = 'Cupressus'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df['GENUS'].loc[df['GENUS'] == '+'] = 'Laburnum'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df.head()
# Out:
#       UNITID                                                                                                                                                                                                 UNITDESC PRIMARYDISTRICTCD BOTANICAL_NAME              SCIENTIFIC_NAME  GROWSPACE  DIAM  CONDITION_RATING               COMMON_NAME  SHAPE_LAT   SHAPE_LNG  TOTAL_RANK  TOTAL_COUNT        GENUS                         PATH
# 0  TRE-48779  1233 39TH AV E                                                                                                                                                                                      ...         DISTRICT3         HAWENG          Crataegus laevigata          8     7                 5  English Midland Hawthorn  47.630875 -122.282937         4.0       7206.0    Crataegus  outdoor_trees/TRE-48779.jpg
# ...

# %%
pathlist = df['PATH'].tolist()

# %%
len(pathlist)
# Out:
# 13825

# %%
missinglist=[]
for p in pathlist:
    if os.path.isfile(p):
        print('yes',p)
    else:
        print('no',p)
        missinglist.append(p)
# Out:
# yes outdoor_trees/TRE-48779.jpg
# yes outdoor_trees/TRE-77899.jpg
# yes outdoor_trees/TRE-80154.jpg
# yes outdoor_trees/TRE-32174.jpg
# yes outdoor_trees/TRE-95011.jpg
# yes outdoor_trees/TRE-61739.jpg
# yes outdoor_trees/TRE-16749.jpg
# yes outdoor_trees/TRE-80296.jpg
# yes outdoor_trees/TRE-9908.jpg
# yes outdoor_trees/TRE-50470.jpg
# yes outdoor_trees/TRE-15236.jpg
# yes outdoor_trees/TRE-28267.jpg
# yes outdoor_trees/TRE-22092.jpg
# yes outdoor_trees/TRE-59690.jpg
# yes outdoor_trees/TRE-84810.jpg
# yes outdoor_trees/TRE-43894.jpg
# yes outdoor_trees/TRE-98643.jpg
# yes outdoor_trees/TRE-58852.jpg
# yes outdoor_trees/TRE-57088.jpg
# yes outdoor_trees/TRE-100312.jpg
# yes outdoor_trees/TRE-4478.jpg
# yes outdoor_trees/TRE-5298.jpg
# yes outdoor_trees/TRE-12314.jpg
# yes outdoor_trees/TRE-14402.jpg
# yes outdoor_trees/TRE-47104.jpg
# yes outdoor_trees/TRE-500855.jpg
# yes outdoor_trees/TRE-81436.jpg
# yes outdoor_trees/TRE-50283.jpg
# yes outdoor_trees/TRE-32398.jpg
# ...

# %%
df = df[~df['PATH'].isin(missinglist)]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12661 entries, 0 to 13999
# Data columns (total 15 columns):
# UNITID               12661 non-null object
# UNITDESC             12661 non-null object
# PRIMARYDISTRICTCD    12661 non-null object
# BOTANICAL_NAME       12661 non-null object
# SCIENTIFIC_NAME      12661 non-null object
# GROWSPACE            12661 non-null int64
# DIAM                 12661 non-null int64
# CONDITION_RATING     12661 non-null int64
# COMMON_NAME          12661 non-null object
# SHAPE_LAT            12661 non-null float64
# SHAPE_LNG            12661 non-null float64
# TOTAL_RANK           12661 non-null float64
# TOTAL_COUNT          12661 non-null float64
# GENUS                12661 non-null object
# PATH                 12661 non-null object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 1.5+ MB

# %%
# PlacesCNN for scene classification


import torch
from torch.autograd import Variable as V
import torchvision.models as models
from torchvision import transforms as trn
from torch.nn import functional as F
import os
from PIL import Image

# th architecture to use
arch = 'resnet50'

# load the pre-trained weights
model_file = '%s_places365.pth.tar' % arch
if not os.access(model_file, os.W_OK):
    weight_url = 'http://places2.csail.mit.edu/models_places365/' + model_file
    os.system('wget ' + weight_url)

model = models.__dict__[arch](num_classes=365)
checkpoint = torch.load(model_file, map_location=lambda storage, loc: storage)
state_dict = {str.replace(k,'module.',''): v for k,v in checkpoint['state_dict'].items()}
model.load_state_dict(state_dict)
model.eval()


# load the image transformer
centre_crop = trn.Compose([
        trn.Resize((256,256)),
        trn.CenterCrop(224),
        trn.ToTensor(),
        trn.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# load the class label
file_name = 'categories_places365.txt'
if not os.access(file_name, os.W_OK):
    synset_url = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
    os.system('wget ' + synset_url)
classes = list()
with open(file_name) as class_file:
    for line in class_file:
        classes.append(line.strip().split(' ')[0][3:])
classes = tuple(classes)

# load the test image
img_name = 'TRE-214.jpg'
if not os.access(img_name, os.W_OK):
    img_url = 'http://places.csail.mit.edu/demo/' + img_name
    os.system('wget ' + img_url)

img = Image.open(img_name)
input_img = V(centre_crop(img).unsqueeze(0))

# forward pass
logit = model.forward(input_img)
h_x = F.softmax(logit, 1).data.squeeze()
probs, idx = h_x.sort(0, True)

print('{} prediction on {}'.format(arch,img_name))
# output the prediction
for i in range(0, 1):
    print('{:.3f} -> {}'.format(probs[i], classes[idx[i]]))
# Out:
# resnet50 prediction on TRE-214.jpg
# 0.412 -> yard

# %%
def classify(image):
    
    img_name = image
    if not os.access(img_name, os.W_OK):
        img_url = 'http://places.csail.mit.edu/demo/' + img_name
        os.system('wget ' + img_url)

    img = Image.open(img_name)
    input_img = V(centre_crop(img).unsqueeze(0))

# forward pass
    logit = model.forward(input_img)
    h_x = F.softmax(logit, 1).data.squeeze()
    probs, idx = h_x.sort(0, True)

    for i in range(0,2):
        scene = classes[idx[i]]
        
    return scene
#    print('{} prediction on {}'.format(arch,img_name))
# output the prediction
#    for i in range(0, 1):
 #       print('{:.3f} -> {}'.format(probs[i], classes[idx[i]]))

# %%
df['SCENE'] = [classify(x) for x in df['PATH']]

# %%
df.sample(10)
# Out:
#           UNITID                                                                                                                                                                                                 UNITDESC PRIMARYDISTRICTCD BOTANICAL_NAME                 SCIENTIFIC_NAME  GROWSPACE  DIAM  CONDITION_RATING                   COMMON_NAME  SHAPE_LAT   SHAPE_LNG  TOTAL_RANK  TOTAL_COUNT          GENUS                         PATH             SCENE
# 5940   TRE-67465  6500 58TH AV NE                                                                                                                                                                                     ...         DISTRICT4         HAWWAS           Crataegus phaenopyrum         99     3                 4           Washington Hawthorn  47.678609 -122.265815         4.0       7206.0      Crataegus  outdoor_trees/TRE-67465.jpg       forest_path
# ...

# %%
df = df[df.UNITID != 'TRE_1028085']

# %%
df = df[df.UNITID != 'TRE-1027008']

# %%
df = df[df.UNITID != 'TRE-1040457']

# %%
df = df[df.UNITID != 'TRE-1040514']

# %%
df = df[df.UNITID != 'TRE-1040459']

# %%
df = df[df.UNITID != 'TRE-50500']

# %%
df = df[df.UNITID != 'TRE-1040287']

# %%
df = df[df.UNITID != 'TRE-41967']

# %%
df = df[df.UNITID != 'TRE-1040302']

# %%
df = df[df.UNITID != 'TRE-50501']

# %%
df = df[df.UNITID != 'TRE-1027374']

# %%
df = df[df.UNITID != 'TRE-1032716']

# %%
df = df[df.UNITID != 'TRE-1040608']

# %%
df = df[df.UNITID != 'TRE-1040609']

# %%
df = df[df.UNITID != 'TRE-83762']

# %%
df = df[df.UNITID != 'TRE-71071']

# %%
df = df[df.UNITID != 'TRE-41873']

# %%
df = df[df.UNITID != 'TRE-1041829']

# %%
df = df[df.UNITID != 'TRE-1028085']

# %%
df = df[df.UNITID != 'TRE-55779']

# %%
df = df[df.UNITID != 'TRE-1040525']

# %%
df = df[df.UNITID != 'TRE-45655']

# %%
df = df[df.UNITID != 'TRE-49681']

# %%
df = df[df.UNITID != 'TRE-68193']

# %%
df = df[df.UNITID != 'TRE-91682']

# %%
df = df[df.UNITID != 'TRE-79339']

# %%
df = df[df.UNITID != 'TRE-42961']

# %%
df = df[df.UNITID != 'TRE-45445']

# %%
df = df[df.UNITID != 'TRE-500924']

# %%
df = df[df.UNITID != 'TRE-80222']

# %%
df = df[df.UNITID != 'TRE-81763']

# %%
df = df[df.UNITID != 'TRE-49920']

# %%
df = df[df.UNITID != 'TRE-1040606']

# %%
df = df[df.UNITID != 'TRE-55743']

# %%
df = df[df.UNITID != 'TRE-32841']

# %%
df = df[df.UNITID != 'TRE-50751']

# %%
df = df[df.UNITID != 'TRE-22133']

# %%
df = df[df.UNITID != 'TRE-41176']

# %%
df = df[df.UNITID != 'TRE-67921']

# %%
df = df[df.UNITID != 'TRE-51267']

# %%
df = df[df.UNITID != 'TRE-37302']

# %%
df = df[df.UNITID != 'TRE-94564']

# %%
df = df[df.UNITID != 'TRE-74270']

# %%
df = df[df.UNITID != 'TRE-80213']

# %%
df = df[df.UNITID != 'TRE-500928']

# %%
df = df[df.UNITID != 'TRE-71056']

# %%
df = df[df.UNITID != 'TRE-103986']

# %%
df = df[df.UNITID != 'TRE-41898']

# %%
df = df[df.UNITID != 'TRE-49716']

# %%
df = df[df.UNITID != 'TRE-95694']

# %%
df = df[df.UNITID != 'TRE-24806']

# %%
df = df[df.UNITID != 'TRE-23909']

# %%
df = df[df.UNITID != 'TRE-91491']

# %%
df = df[df.UNITID != 'TRE-81760']

# %%
df = df[df.UNITID != 'TRE-76626']

# %%
df = df[df.UNITID != 'TRE-23907']

# %%
df = df[df.UNITID != 'TRE-37655']

# %%
df = df[df.UNITID != 'TRE-82001']

# %%
df = df[df.UNITID != 'TRE-41675']

# %%
df = df[df.UNITID != 'TRE-56162']

# %%
df = df[df.UNITID != 'TRE-91950']

# %%
df = df[df.UNITID != 'TRE-22128']

# %%
df = df[df.UNITID != 'TRE-45161']

# %%
df = df[df.UNITID != 'TRE-42949']

# %%
df = df[df.UNITID != 'TRE-42945']

# %%
df = df[df.UNITID != 'TRE-14509']

# %%
df = df[df.UNITID != 'TRE-91819']

# %%
df = df[df.UNITID != 'TRE-42956']

# %%
df = df[df.UNITID != 'TRE-40901']

# %%
df = df[df.UNITID != 'TRE-68519']

# %%
df = df[df.UNITID != 'TRE-5824']

# %%
df = df[df.UNITID != 'TRE-24911']

# %%
df = df[df.UNITID != 'TRE-85280']

# %%
df = df[df.UNITID != 'TRE-49702']

# %%
df = df[df.UNITID != 'TRE-68291']

# %%
df = df[df.UNITID != 'TRE-56003']

# %%
df = df[df.UNITID != 'TRE-50589']

# %%
df = df[df.UNITID != 'TRE-76579']

# %%
df = df[df.UNITID != 'TRE-70960']

# %%
df = df[df.UNITID != 'TRE-50053']

# %%
df = df[df.UNITID != 'TRE-53869']

# %%
df = df[df.UNITID != 'TRE-88']

# %%
df = df[df.UNITID != 'TRE-37447']

# %%
df = df[df.UNITID != 'TRE-1040963']

# %%
df = df[df.UNITID != 'TRE-45171']

# %%
df = df[df.UNITID != 'TRE-32598']

# %%
df = df[df.UNITID != 'TRE-39692']

# %%
df = df[df.UNITID != 'TRE-75091']

# %%
df = df[df.UNITID != 'TRE-41891']

# %%
df = df[df.UNITID != 'TRE-71058']

# %%
df = df[df.UNITID != 'TRE-53728']

# %%
df = df[df.UNITID != 'TRE-91821']

# %%
df = df[df.UNITID != 'TRE-75423']

# %%
df = df[df.UNITID != 'TRE-56418']

# %%
df = df[df.UNITID != 'TRE-16810']

# %%
df = df[df.UNITID != 'TRE-71684']

# %%
df = df[df.UNITID != 'TRE-78026']

# %%
df = df[df.UNITID != 'TRE-64008']

# %%
df = df[df.UNITID != 'TRE-1040393']

# %%
df = df[df.UNITID != 'TRE-74323']

# %%
df = df[df.UNITID != 'TRE-95981']

# %%
df = df[df.UNITID != 'TRE-42665']

# %%
df = df[df.UNITID != 'TRE-3885']

# %%
df = df[df.UNITID != 'TRE-60922']

# %%
df = df[df.UNITID != 'TRE-67929']

# %%
df = df[df.UNITID != 'TRE-165']

# %%
df = df[df.UNITID != 'TRE-62934']

# %%
df = df[df.UNITID != 'TRE-78028']

# %%
df = df[df.UNITID != 'TRE-105916']

# %%
df = df[df.UNITID != 'TRE-34294']

# %%
df = df[df.UNITID != 'TRE-97168']

# %%
df = df[df.UNITID != 'TRE-8877']

# %%
df = df[df.UNITID != 'TRE-76115']

# %%
df = df[df.UNITID != 'TRE-84423']

# %%
df = df[df.UNITID != 'TRE-82016']

# %%
df = df[df.UNITID != 'TRE-100130']

# %%
df.to_pickle("df_trees.pkl")

# %%
df['SCENE'].value_counts()

# %%
df.loc[df['SCENE'] == 'industrial_area']
# Out:
#             UNITID                                                                                                                                                                                                 UNITDESC PRIMARYDISTRICTCD BOTANICAL_NAME                 SCIENTIFIC_NAME  GROWSPACE  DIAM  CONDITION_RATING                     COMMON_NAME  SHAPE_LAT   SHAPE_LNG  TOTAL_RANK  TOTAL_COUNT         GENUS                           PATH            SCENE
# 29       TRE-78026  3301 6TH AVE S                                                                                                                                                                                      ...         DISTRICT2         MAPNOR                Acer platanoides         10    10                 3                    Norway Maple  47.574133 -122.326136         1.0      32046.0          Acer    outdoor_trees/TRE-78026.jpg  industrial_area
# ...

# %%
df = pd.read_pickle("df_trees.pkl")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12548 entries, 0 to 13999
# Data columns (total 16 columns):
# UNITID               12548 non-null object
# UNITDESC             12548 non-null object
# PRIMARYDISTRICTCD    12548 non-null object
# BOTANICAL_NAME       12548 non-null object
# SCIENTIFIC_NAME      12548 non-null object
# GROWSPACE            12548 non-null int64
# DIAM                 12548 non-null int64
# CONDITION_RATING     12548 non-null int64
# COMMON_NAME          12548 non-null object
# SHAPE_LAT            12548 non-null float64
# SHAPE_LNG            12548 non-null float64
# TOTAL_RANK           12548 non-null float64
# TOTAL_COUNT          12548 non-null float64
# GENUS                12548 non-null object
# PATH                 12548 non-null object
# SCENE                12548 non-null object
# dtypes: float64(4), int64(3), object(9)
# memory usage: 1.6+ MB

# %%
df_testing = df

# %%
df_testing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 0 to 13999
# Data columns (total 16 columns):
# UNITID               10000 non-null object
# UNITDESC             10000 non-null object
# PRIMARYDISTRICTCD    10000 non-null object
# BOTANICAL_NAME       10000 non-null object
# SCIENTIFIC_NAME      10000 non-null object
# GROWSPACE            10000 non-null int64
# DIAM                 10000 non-null int64
# CONDITION_RATING     10000 non-null int64
# COMMON_NAME          10000 non-null object
# SHAPE_LAT            10000 non-null float64
# SHAPE_LNG            10000 non-null float64
# TOTAL_RANK           10000 non-null float64
# TOTAL_COUNT          10000 non-null float64
# GENUS                10000 non-null object
# PATH                 10000 non-null object
# SCENE                10000 non-null object
# dtypes: float64(4), int64(3), object(9)
# memory usage: 1.3+ MB

# %%
df_testing['SCENE'].value_counts()
# Out:
# residential_neighborhood    1328
# tree_farm                    985
# driveway                     954
# manufactured_home            704
# orchard                      640
# yard                         579
# botanical_garden             579
# house                        563
# park                         356
# japanese_garden              294
# cottage                      283
# campus                       219
# roof_garden                  201
# beach_house                  186
# zen_garden                   185
# forest/broadleaf             173
# picnic_area                  161
# tree_house                   157
# forest_road                  156
# topiary_garden               144
# oast_house                   142
# formal_garden                115
# library/outdoor               86
# hunting_lodge/outdoor         83
# mansion                       76
# forest_path                   71
# rainforest                    64
# inn/outdoor                   56
# ...

# %%
df_testing = df_testing[df_testing.SCENE != 'industrial_area']

# %%
df_testing = df_testing[df_testing.SCENE != 'construction_site']

# %%
df_testing = df_testing[df_testing.SCENE != 'alley']

# %%
df_testing = df_testing[df_testing.SCENE != 'shopping_mall/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'igloo']

# %%
df_testing = df_testing[df_testing.SCENE != 'museum/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'train_station/platform']

# %%
df_testing = df_testing[df_testing.SCENE != 'repair_shop']

# %%
df_testing = df_testing[df_testing.SCENE != 'supermarket']

# %%
df_testing = df_testing[df_testing.SCENE != 'ball_pit']

# %%
df_testing = df_testing[df_testing.SCENE != 'mezzanine']

# %%
df_testing = df_testing[df_testing.SCENE != 'ice_skating_rink/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'swimming_pool/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'parking_garage/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'shower']

# %%
df_testing = df_testing[df_testing.SCENE != 'fire_escape']

# %%
df_testing = df_testing[df_testing.SCENE != 'bus_station/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'loading_dock']

# %%
df_testing = df_testing[df_testing.SCENE != 'hangar/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'restaurant_patio']

# %%
df_testing = df_testing[df_testing.SCENE != 'ticket_booth']

# %%
df_testing = df_testing[df_testing.SCENE != 'staircase']

# %%
df_testing = df_testing[df_testing.SCENE != 'junkyard']

# %%
df_testing = df_testing[df_testing.SCENE != 'highway']

# %%
df_testing = df_testing[df_testing.SCENE != 'parking_garage/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'parking_lot']

# %%
df_testing = df_testing[df_testing.SCENE != 'motel']

# %%
df_testing = df_testing[df_testing.SCENE != 'excavation']

# %%
df_testing = df_testing[df_testing.SCENE != 'skyscraper']

# %%
df_testing = df_testing[df_testing.SCENE != 'volleyball_court/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'beer_garden']

# %%
df_testing = df_testing[df_testing.SCENE != 'cliff']

# %%
df_testing = df_testing[df_testing.SCENE != 'landfill']

# %%
df_testing = df_testing[df_testing.SCENE != 'boathouse']

# %%
df_testing = df_testing[df_testing.SCENE != 'market/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'lighthouse']

# %%
df_testing = df_testing[df_testing.SCENE != 'tundra']

# %%
df_testing = df_testing[df_testing.SCENE != 'corral']

# %%
df_testing = df_testing[df_testing.SCENE != 'wind_farm']

# %%
df_testing = df_testing[df_testing.SCENE != 'barndoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'fountain']

# %%
df_testing = df_testing[df_testing.SCENE != 'dam']

# %%
df_testing = df_testing[df_testing.SCENE != 'viaduct']

# %%
df_testing = df_testing[df_testing.SCENE != 'aqueduct']

# %%
df_testing = df_testing[df_testing.SCENE != 'tower']

# %%
df_testing = df_testing[df_testing.SCENE != 'garage/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'fastfood_restaurant']

# %%
df_testing = df_testing[df_testing.SCENE != 'desert_road']

# %%
df_testing = df_testing[df_testing.SCENE != 'sky']

# %%
df_testing = df_testing[df_testing.SCENE != 'balcony/exterior']

# %%
df_testing = df_testing[df_testing.SCENE != 'gas_station']

# %%
df_testing = df_testing[df_testing.SCENE != 'amusement_park']

# %%
df_testing = df_testing[df_testing.SCENE != 'railroad_track']

# %%
df_testing = df_testing[df_testing.SCENE != 'phone_booth']

# %%
df_testing = df_testing[df_testing.SCENE != 'amphitheater']

# %%
df_testing = df_testing[df_testing.SCENE != 'pharmacy']

# %%
df_testing = df_testing[df_testing.SCENE != 'hardware_store']

# %%
df_testing = df_testing[df_testing.SCENE != 'fire_station']

# %%
df_testing = df_testing[df_testing.SCENE != 'hardware_store']

# %%
df_testing = df_testing[df_testing.SCENE != 'doorway/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'general_store/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'shopfront']

# %%
df_testing = df_testing[df_testing.SCENE != 'palace']

# %%
df_testing = df_testing[df_testing.SCENE != 'water_tower']

# %%
df_testing = df_testing[df_testing.SCENE != 'courthouse']

# %%
df_testing = df_testing[df_testing.SCENE != 'kennel/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'pavilion']

# %%
df_testing = df_testing[df_testing.SCENE != 'diner/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'embassy']

# %%
df_testing = df_testing[df_testing.SCENE != 'hospital']

# %%
df_testing = df_testing[df_testing.SCENE != 'office_building ']

# %%
df_testing = df_testing[df_testing.SCENE != 'rope_bridge']

# %%
df_testing = df_testing[df_testing.SCENE != 'windwill']

# %%
df_testing = df_testing[df_testing.SCENE != 'shed']

# %%
df_testing = df_testing[df_testing.SCENE != 'office_building']

# %%
df_testing = df_testing[df_testing.SCENE != 'mausoleum']

# %%
df_testing = df_testing[df_testing.SCENE != 'windwill']

# %%
df_testing = df_testing[df_testing.SCENE != 'street']

# %%
df_testing = df_testing[df_testing.SCENE != 'building_facade']

# %%
df_testing = df_testing[df_testing.SCENE != 'apartment_building/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'promenade']

# %%
df_testing = df_testing[df_testing.SCENE != 'courtyard']

# %%
df_testing = df_testing[df_testing.SCENE != 'windmill']

# %%
df_testing = df_testing[df_testing.SCENE != 'greenhouse/indoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'patio']

# %%
df_testing = df_testing[df_testing.SCENE != 'hotel/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'boardwalk']

# %%
df_testing = df_testing[df_testing.SCENE != 'field_road']

# %%
df_testing = df_testing[df_testing.SCENE != 'pasture']

# %%
df_testing = df_testing[df_testing.SCENE != 'barn']

# %%
df_testing = df_testing[df_testing.SCENE != 'downtown']

# %%
df_testing = df_testing[df_testing.SCENE != 'mountain']

# %%
df_testing = df_testing[df_testing.SCENE != 'valley']

# %%
df_testing = df_testing[df_testing.SCENE != 'farm']

# %%
df_testing = df_testing[df_testing.SCENE != 'museum/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'moat/water']

# %%
df_testing = df_testing[df_testing.SCENE != 'atrium/public']

# %%
df_testing = df_testing[df_testing.SCENE != 'crosswalk']

# %%
df_testing = df_testing[df_testing.SCENE != 'soccer_field']

# %%
df_testing = df_testing[df_testing.SCENE != 'baseball_field']

# %%
df_testing = df_testing[df_testing.SCENE != 'athletic_field/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'marsh']

# %%
df_testing = df_testing[df_testing.SCENE != 'canal/natural']

# %%
df_testing = df_testing[df_testing.SCENE != 'creek']

# %%
df_testing = df_testing[df_testing.SCENE != 'river']

# %%
df_testing = df_testing[df_testing.SCENE != 'corn_field']

# %%
df_testing = df_testing[df_testing.SCENE != 'plaza']

# %%
df_testing = df_testing[df_testing.SCENE != 'church/outdoor']

# %%
df_testing = df_testing[df_testing.SCENE != 'castle']

# %%
df_testing.to_pickle("df_testing.pkl")

# %%
df_testing.sample(10)
# Out:
#           UNITID                                                                                                                                                                                                 UNITDESC PRIMARYDISTRICTCD BOTANICAL_NAME                 SCIENTIFIC_NAME  GROWSPACE  DIAM  CONDITION_RATING                   COMMON_NAME  SHAPE_LAT   SHAPE_LNG  TOTAL_RANK  TOTAL_COUNT        GENUS                         PATH                     SCENE        FAMILY
# 8853   TRE-41420  1235 10TH AV W                                                                                                                                                                                      ...         DISTRICT7         CHEYOS              Prunus x yedoensis         10     3                 5                Yoshino Cherry  47.630548 -122.370497         2.0      26753.0       Prunus  outdoor_trees/TRE-41420.jpg                   cottage      Rosaceae
# ...

# %%
df_testing['FAMILY'] = df_testing['GENUS']

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Prunus'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Acer'] = 'Sapindaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Crataegus'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Malus'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Betula'] = 'Betulaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Liquidambar'] = 'Altingiaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Tilia'] = 'Malvaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Quercus'] = 'Fagaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cornus'] = 'Cornaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Platanus'] = 'Plantanaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Carpinus'] = 'Betulaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Styrax'] = 'Styracaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Magnolia'] = 'Magnoliaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Pyrus'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Fraxinus'] = 'Oleaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Thuja'] = 'Cupressoideae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Gleditsia'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Sorbus'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Amelanchier'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Pseudotsuga'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Aesculus'] = 'Sapindaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Sapindales'] = 'Sapindaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Pinus'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Zelkova'] = 'Ulmaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cupressoideae'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cercis'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ulmus'] = 'Ulmaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Chamaecyparis'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Fagus'] = 'Fagaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ilex'] = 'Aquifoliaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Robinia'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Catalpa'] = 'Bignoniaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Populus'] = 'Salicaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Liriodendron'] = 'Magnoliaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ginkgo'] = 'Gingkoaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Picea'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cercidiphyllum'] = 'Cercidiphyllaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Picea'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Syringa'] = 'Oleaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Abies'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Photinia'] = 'Rosaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cedrus'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Laburnum'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Tsuga'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Corylus'] = 'Betulaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Stewartia'] = 'Theaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Alnus'] = 'Betulaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Albizia'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Salix'] = 'Salicaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Castanea'] = 'Fagaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Koelreuteria'] = 'Sapindaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Juglans'] = 'Juglandaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cupressus'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Calocedrus'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Rhus'] = 'Anacardiaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Nyssa'] = 'Nyssaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Arbutus'] = 'Ericaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Parrotia'] = 'Hamamelidaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Juniperus'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Sequoia'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Lingustrum'] = 'Oleaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Rhododendron'] = 'Ericaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Hibiscus'] = 'Malvaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Clerodendrum'] = 'Lamiaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ficus'] = 'Moraceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Sophora'] = 'Fabaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Eucalyptus'] = 'Myrtaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Metasequoia'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Davidia'] = 'Nyssaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cotinus'] = 'Anacardiaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Phellodendron'] = 'Rutaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Laurus'] = 'Lauraceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Elaeagnus'] = 'Elaeagnaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Morus'] = 'Moraceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Umbellularia'] = 'Lauraceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Nothofagus'] = 'Nothofagaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Araucaria'] = 'Araucariaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ligustrum'] = 'Oleaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Larix'] = 'Pinaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Olea'] = 'Oleaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Sequoiadendron'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Lagerstroemia'] = 'Lythraceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Ailanthus'] = 'Simaroubaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Cryptomeria'] = 'Cupressaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].loc[df_testing['FAMILY'] == 'Oxydendrum'] = 'Ericaceae'
# Out:
# /home/carnd/anaconda3/lib/python3.5/site-packages/pandas/core/indexing.py:132: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
df_testing['FAMILY'].value_counts()
# Out:
# Rosaceae             4578
# Sapindaceae          1779
# Betulaceae            549
# Fagaceae              330
# Altingiaceae          294
# Pinaceae              294
# Malvaceae             276
# Cornaceae             273
# Fabaceae              272
# Cupressaceae          224
# Oleaceae              224
# Plantanaceae          158
# Magnoliaceae          145
# Ulmaceae              127
# Styracaceae           125
# Cercidiphyllaceae      88
# Aquifoliaceae          49
# Salicaceae             46
# Bignoniaceae           40
# Gingkoaceae            28
# Theaceae               19
# Anacardiaceae          14
# Juglandaceae           13
# Nyssaceae              11
# Ericaceae              11
# Hamamelidaceae          9
# Moraceae                6
# Lauraceae               4
# Rutaceae                3
# Myrtaceae               3
# Elaeagnaceae            2
# Nothofagaceae           2
# Lamiaceae               1
# Lythraceae              1
# Araucariaceae           1
# ...
